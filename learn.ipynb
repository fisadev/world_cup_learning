# %%
from random import random

from IPython.display import HTML
import pygal
from sklearn.neighbors import KNeighborsClassifier

from utils import get_matches, get_team_stats, extract_samples, normalize, split_samples

# %% [markdown]
# Configs:

# %%
input_features = ['year',
                  'matches_won_percent',
                  'podium_score_yearly',
                  'matches_won_percent_2',
                  'podium_score_yearly_2']

output_feature = 'winner'

remove_ties = True

neighbors = 10

# %%
team_stats = get_team_stats()
team_stats.head()
# Out:
#                        matches_played  matches_won  years_played  \
# team
# Brazil                             89           63            16
# Canada                              3            0             1
# Serbia and Montenegro               3            0             1
# Kuwait                              3            0             1
# Scotland                           23            4             8
#
#                        podium_score  cups_won  matches_won_percent  \
# team
# Brazil                          102         5            70.786517
# Canada                            0         0             0.000000
# Serbia and Montenegro             0         0             0.000000
# Kuwait                            0         0             0.000000
# Scotland                          0         0            17.391304
#
#                        podium_score_yearly  cups_won_yearly
# team
# Brazil                               6.375           0.3125
# Canada                               0.000           0.0000
# Serbia and Montenegro                0.000           0.0000
# Kuwait                               0.000           0.0000
# Scotland                             0.000           0.0000
#
# [5 rows x 8 columns]

# %%
def teams_by_stat_graph(stat):
    sorted_team_stats = team_stats.sort(stat)
    graph = pygal.Bar()
    graph.title = 'Teams by ' + stat
    graph.x_labels = list(sorted_team_stats.index)
    graph.add(stat, sorted_team_stats[stat])

    return HTML(graph.render())

# %%
teams_by_stat_graph('matches_won_percent')
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-dbf565ed-a9b5-4f06-b563-a635780d1396" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 1.4.6 ©Kozea 2011-2014 on 2014-05-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .title{font-family:monospace;font-size:16px}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .legends .legend text{font-family:monospace;font-size:14px}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis text{font-family:monospace;font-size:10px}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis text.major{font-family:monospace;font-size:10px}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .series text{font-family:monospace;font-size:8px}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .tooltip text{font-family:monospace;font-size:16px}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 text.no_data{font-size:64px}
# #chart-dbf565ed-a9b5-4f06-b563-a635780d1396{background-color:black}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 path,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 line,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 rect,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .graph &gt; .background{fill:black}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .plot &gt; .background{fill:#111}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .graph{fill:#999}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 text.no_data{fill:#eee}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .title{fill:#eee}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .legends .legend text{fill:#999}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .legends .legend:hover text{fill:#eee}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis .line{stroke:#eee}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis .guide.line{stroke:#555}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis .major.line{stroke:#999}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis text.major{stroke:#eee;fill:#eee}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis.y .guides:hover .guide.line,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .line-graph .axis.x .guides:hover .guide.line,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis .guides:hover text{fill:#eee}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .reactive{fill-opacity:.8}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .reactive.active,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .active .reactive{fill-opacity:.4}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .series text{fill:#eee}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .tooltip rect{fill:#111;stroke:#eee}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .tooltip text{fill:#eee}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .map-element{fill:#999;stroke:#555 !important;opacity:.9;stroke-width:3;-webkit-transition:250ms;-moz-transition:250ms;-o-transition:250ms;transition:250ms}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .map-element:hover{opacity:1;stroke-width:10}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-0,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-0 a:visited{stroke:#ff5995;fill:#ff5995}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-1,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-1 a:visited{stroke:#b6e354;fill:#b6e354}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-2,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-2 a:visited{stroke:#feed6c;fill:#feed6c}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-3,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-3 a:visited{stroke:#8cedff;fill:#8cedff}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-4,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-4 a:visited{stroke:#9e6ffe;fill:#9e6ffe}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-5,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-5 a:visited{stroke:#899ca1;fill:#899ca1}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-6,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-6 a:visited{stroke:#f8f8f2;fill:#f8f8f2}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-7,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-7 a:visited{stroke:#bf4646;fill:#bf4646}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-8,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-8 a:visited{stroke:#516083;fill:#516083}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-9,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-9 a:visited{stroke:#f92672;fill:#f92672}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-10,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-10 a:visited{stroke:#82b414;fill:#82b414}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-11,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .color-11 a:visited{stroke:# ...
# #chart-dbf565ed-a9b5-4f06-b563-a635780d1396 text.no_data{text-anchor:middle}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .guide.line{fill-opacity:0}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .centered{text-anchor:middle}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .title{text-anchor:middle}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .legends .legend text{fill-opacity:1}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis.x text{text-anchor:middle}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis.y text{text-anchor:end}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis.y2 text{text-anchor:start}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis.y .logarithmic text:not(.major),#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis.y2 .logarithmic text:not(.major){font-size:50%}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis .guide.line{stroke-dasharray:4,4}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis .major.guide.line{stroke-dasharray:6,6}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis text.major{stroke-width:0.5px}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .horizontal .axis.y .guide.line,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .horizontal .axis.y2 .guide.line,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .vertical .axis.x .guide.line{opacity:0}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .horizontal .axis.always_show .guide.line,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis.y .guides:hover .guide.line,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis.y2 .guides:hover .guide.line,#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis.x .guides:hover .guide.line{opacity:1}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .axis .guides:hover text{opacity:1}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .nofill{fill:none}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .subtle-fill{fill-opacity:.2}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .dot{stroke-width:1px;fill-opacity:1}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .dot.active{stroke-width:5px}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .series text{stroke:none}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .series text.active{opacity:1}#chart-dbf565ed-a9b5-4f06-b563-a635780d1396 .tooltip rect{fill-opacity:0.8}#chart-

# %%
teams_by_stat_graph('podium_score_yearly')
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-375d444f-a894-41f8-942e-a8a565780d55" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 1.4.6 ©Kozea 2011-2014 on 2014-05-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-375d444f-a894-41f8-942e-a8a565780d55 .title{font-family:monospace;font-size:16px}#chart-375d444f-a894-41f8-942e-a8a565780d55 .legends .legend text{font-family:monospace;font-size:14px}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis text{font-family:monospace;font-size:10px}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis text.major{font-family:monospace;font-size:10px}#chart-375d444f-a894-41f8-942e-a8a565780d55 .series text{font-family:monospace;font-size:8px}#chart-375d444f-a894-41f8-942e-a8a565780d55 .tooltip text{font-family:monospace;font-size:16px}#chart-375d444f-a894-41f8-942e-a8a565780d55 text.no_data{font-size:64px}
# #chart-375d444f-a894-41f8-942e-a8a565780d55{background-color:black}#chart-375d444f-a894-41f8-942e-a8a565780d55 path,#chart-375d444f-a894-41f8-942e-a8a565780d55 line,#chart-375d444f-a894-41f8-942e-a8a565780d55 rect,#chart-375d444f-a894-41f8-942e-a8a565780d55 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-375d444f-a894-41f8-942e-a8a565780d55 .graph &gt; .background{fill:black}#chart-375d444f-a894-41f8-942e-a8a565780d55 .plot &gt; .background{fill:#111}#chart-375d444f-a894-41f8-942e-a8a565780d55 .graph{fill:#999}#chart-375d444f-a894-41f8-942e-a8a565780d55 text.no_data{fill:#eee}#chart-375d444f-a894-41f8-942e-a8a565780d55 .title{fill:#eee}#chart-375d444f-a894-41f8-942e-a8a565780d55 .legends .legend text{fill:#999}#chart-375d444f-a894-41f8-942e-a8a565780d55 .legends .legend:hover text{fill:#eee}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis .line{stroke:#eee}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis .guide.line{stroke:#555}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis .major.line{stroke:#999}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis text.major{stroke:#eee;fill:#eee}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis.y .guides:hover .guide.line,#chart-375d444f-a894-41f8-942e-a8a565780d55 .line-graph .axis.x .guides:hover .guide.line,#chart-375d444f-a894-41f8-942e-a8a565780d55 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-375d444f-a894-41f8-942e-a8a565780d55 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis .guides:hover text{fill:#eee}#chart-375d444f-a894-41f8-942e-a8a565780d55 .reactive{fill-opacity:.8}#chart-375d444f-a894-41f8-942e-a8a565780d55 .reactive.active,#chart-375d444f-a894-41f8-942e-a8a565780d55 .active .reactive{fill-opacity:.4}#chart-375d444f-a894-41f8-942e-a8a565780d55 .series text{fill:#eee}#chart-375d444f-a894-41f8-942e-a8a565780d55 .tooltip rect{fill:#111;stroke:#eee}#chart-375d444f-a894-41f8-942e-a8a565780d55 .tooltip text{fill:#eee}#chart-375d444f-a894-41f8-942e-a8a565780d55 .map-element{fill:#999;stroke:#555 !important;opacity:.9;stroke-width:3;-webkit-transition:250ms;-moz-transition:250ms;-o-transition:250ms;transition:250ms}#chart-375d444f-a894-41f8-942e-a8a565780d55 .map-element:hover{opacity:1;stroke-width:10}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-0,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-0 a:visited{stroke:#ff5995;fill:#ff5995}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-1,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-1 a:visited{stroke:#b6e354;fill:#b6e354}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-2,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-2 a:visited{stroke:#feed6c;fill:#feed6c}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-3,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-3 a:visited{stroke:#8cedff;fill:#8cedff}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-4,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-4 a:visited{stroke:#9e6ffe;fill:#9e6ffe}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-5,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-5 a:visited{stroke:#899ca1;fill:#899ca1}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-6,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-6 a:visited{stroke:#f8f8f2;fill:#f8f8f2}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-7,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-7 a:visited{stroke:#bf4646;fill:#bf4646}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-8,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-8 a:visited{stroke:#516083;fill:#516083}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-9,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-9 a:visited{stroke:#f92672;fill:#f92672}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-10,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-10 a:visited{stroke:#82b414;fill:#82b414}#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-11,#chart-375d444f-a894-41f8-942e-a8a565780d55 .color-11 a:visited{stroke:# ...
# #chart-375d444f-a894-41f8-942e-a8a565780d55 text.no_data{text-anchor:middle}#chart-375d444f-a894-41f8-942e-a8a565780d55 .guide.line{fill-opacity:0}#chart-375d444f-a894-41f8-942e-a8a565780d55 .centered{text-anchor:middle}#chart-375d444f-a894-41f8-942e-a8a565780d55 .title{text-anchor:middle}#chart-375d444f-a894-41f8-942e-a8a565780d55 .legends .legend text{fill-opacity:1}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis.x text{text-anchor:middle}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis.y text{text-anchor:end}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis.y2 text{text-anchor:start}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis.y .logarithmic text:not(.major),#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis.y2 .logarithmic text:not(.major){font-size:50%}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis .guide.line{stroke-dasharray:4,4}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis .major.guide.line{stroke-dasharray:6,6}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis text.major{stroke-width:0.5px}#chart-375d444f-a894-41f8-942e-a8a565780d55 .horizontal .axis.y .guide.line,#chart-375d444f-a894-41f8-942e-a8a565780d55 .horizontal .axis.y2 .guide.line,#chart-375d444f-a894-41f8-942e-a8a565780d55 .vertical .axis.x .guide.line{opacity:0}#chart-375d444f-a894-41f8-942e-a8a565780d55 .horizontal .axis.always_show .guide.line,#chart-375d444f-a894-41f8-942e-a8a565780d55 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis.y .guides:hover .guide.line,#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis.y2 .guides:hover .guide.line,#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis.x .guides:hover .guide.line{opacity:1}#chart-375d444f-a894-41f8-942e-a8a565780d55 .axis .guides:hover text{opacity:1}#chart-375d444f-a894-41f8-942e-a8a565780d55 .nofill{fill:none}#chart-375d444f-a894-41f8-942e-a8a565780d55 .subtle-fill{fill-opacity:.2}#chart-375d444f-a894-41f8-942e-a8a565780d55 .dot{stroke-width:1px;fill-opacity:1}#chart-375d444f-a894-41f8-942e-a8a565780d55 .dot.active{stroke-width:5px}#chart-375d444f-a894-41f8-942e-a8a565780d55 .series text{stroke:none}#chart-375d444f-a894-41f8-942e-a8a565780d55 .series text.active{opacity:1}#chart-375d444f-a894-41f8-942e-a8a565780d55 .tooltip rect{fill-opacity:0.8}#chart-

# %%
matches = get_matches(with_team_stats=True,
                      duplicate_with_reversed=True)

if remove_ties:
        matches = matches[matches['score1'] != matches['score2']]
        
matches.head()
# Out:
#    score1  score2        team1        team2  year  score_diff  winner  \
# 0       4       0       Brazil       Mexico  1950           4       1
# 1       3       0   Yugoslavia  Switzerland  1950           3       1
# 3       4       1   Yugoslavia       Mexico  1950           3       1
# 4       2       0       Brazil   Yugoslavia  1950           2       1
# 5       2       1  Switzerland       Mexico  1950           1       1
#
#    matches_played  matches_won  years_played  podium_score  cups_won  \
# 0              89           63            16           102         5
# 1              34           14             8             2         0
# 3              34           14             8             2         0
# 4              89           63            16           102         5
# 5              24            7             7             0         0
#
#    matches_won_percent  podium_score_yearly  cups_won_yearly  \
# 0            70.786517                6.375           0.3125
# 1            41.176471                0.250           0.0000
# 3            41.176471                0.250           0.0000
# 4            70.786517                6.375           0.3125
# 5            29.166667                0.000           0.0000
#
#    matches_played_2  matches_won_2  years_played_2  podium_score_2  \
# 0                46             12              13               0
# 1                24              7               7               0
# 3                46             12              13               0
# 4                34             14               8               2
# 5                46             12              13               0
#
#    cups_won_2
# 0           0 ...
# 1           0 ...
# 3           0 ...
# 4           0 ...
# 5           0 ...
#
# [5 rows x 23 columns]

# %%
inputs, outputs = extract_samples(matches,
                                  input_features,
                                  output_feature)

normalizer, inputs = normalize(inputs)

train_inputs, train_outputs, test_inputs, test_outputs = split_samples(inputs, outputs)

classifier = KNeighborsClassifier(n_neighbors=neighbors)
classifier.fit(train_inputs, train_outputs)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            n_neighbors=10, p=2, weights='uniform')

# %%
classifier.score(test_inputs, test_outputs)
# Out:
# 0.7350427350427351

# %%
from utils import get_matches, get_team_stats, extract_samples, normalize, split_samples
from sklearn.neighbors import KNeighborsClassifier
from random import random

# %% [markdown]
# Configs:

# %%
input_features = ['year',
                  'matches_won_percent',
                  'podium_score_yearly',
                  'matches_won_percent_2',
                  'podium_score_yearly_2']

output_feature = 'winner'

remove_ties = True

neighbors = 10

# %%
team_stats = get_team_stats()
team_stats.head()
# Out:
#                        matches_played  matches_won  years_played  \
# team
# Brazil                             89           63            16
# Canada                              3            0             1
# Serbia and Montenegro               3            0             1
# Kuwait                              3            0             1
# Scotland                           23            4             8
#
#                        podium_score  cups_won  matches_won_percent  \
# team
# Brazil                          102         5            70.786517
# Canada                            0         0             0.000000
# Serbia and Montenegro             0         0             0.000000
# Kuwait                            0         0             0.000000
# Scotland                          0         0            17.391304
#
#                        podium_score_yearly  cups_won_yearly
# team
# Brazil                               6.375           0.3125
# Canada                               0.000           0.0000
# Serbia and Montenegro                0.000           0.0000
# Kuwait                               0.000           0.0000
# Scotland                             0.000           0.0000
#
# [5 rows x 8 columns]

# %%
matches = get_matches(with_team_stats=True,
                      duplicate_with_reversed=True)

if remove_ties:
        matches = matches[matches['score1'] != matches['score2']]
        
matches.head()
# Out:
#    score1  score2        team1        team2  year  score_diff  winner  \
# 0       4       0       Brazil       Mexico  1950           4       1
# 1       3       0   Yugoslavia  Switzerland  1950           3       1
# 3       4       1   Yugoslavia       Mexico  1950           3       1
# 4       2       0       Brazil   Yugoslavia  1950           2       1
# 5       2       1  Switzerland       Mexico  1950           1       1
#
#    matches_played  matches_won  years_played  podium_score  cups_won  \
# 0              89           63            16           102         5
# 1              34           14             8             2         0
# 3              34           14             8             2         0
# 4              89           63            16           102         5
# 5              24            7             7             0         0
#
#    matches_won_percent  podium_score_yearly  cups_won_yearly  \
# 0            70.786517                6.375           0.3125
# 1            41.176471                0.250           0.0000
# 3            41.176471                0.250           0.0000
# 4            70.786517                6.375           0.3125
# 5            29.166667                0.000           0.0000
#
#    matches_played_2  matches_won_2  years_played_2  podium_score_2  \
# 0                46             12              13               0
# 1                24              7               7               0
# 3                46             12              13               0
# 4                34             14               8               2
# 5                46             12              13               0
#
#    cups_won_2
# 0           0 ...
# 1           0 ...
# 3           0 ...
# 4           0 ...
# 5           0 ...
#
# [5 rows x 23 columns]

# %%
inputs, outputs = extract_samples(matches,
                                  input_features,
                                  output_feature)

normalizer, inputs = normalize(inputs)

train_inputs, train_outputs, test_inputs, test_outputs = split_samples(inputs, outputs)

classifier = KNeighborsClassifier(n_neighbors=neighbors)
classifier.fit(train_inputs, train_outputs)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            n_neighbors=10, p=2, weights='uniform')

# %%
classifier.score(test_inputs, test_outputs)
# Out:
# 0.71923076923076923

# %%
def get_classifier_input(team1, team2):
    input_line = []
    for feature in input_features:
        if feature.endswith('_2'):
            team = team2
        else:
            team = team1
        
        feature = feature.replace('_2', '')
        feature_value = team_stats.loc[team, feature]
        input_line.append(feature_value)
        
    return input_line

# %%
get_classifier_input('Argentina', 'Brazil', 2014)
# Out:
# [51.5625, 3.0769230769230771, 70.786516853932582, 6.375]

# %%
classifier.predict(get_classifier_input('Brazil', 'Argentina'))
# Out:
# array([1])

# %%
classifier.predict(get_classifier_input('Haiti', 'Argentina'))
# Out:
# array([2])

# %%
classifier.predict(get_classifier_input('Argentina', 'Germany'))
# Out:
# array([1])

# %%
team_stats.sort('matches_won_percent').tail()
# Out:
#              matches_played  matches_won  years_played  podium_score  \
# team
# Argentina                64           33            13            40
# Portugal                 23           12             5             6
# Netherlands              41           22             7            26
# Germany                  98           59            15            94
# Brazil                   89           63            16           102
#
#              cups_won  matches_won_percent  podium_score_yearly  \
# team
# Argentina           2            51.562500             3.076923
# Portugal            0            52.173913             1.200000
# Netherlands         0            53.658537             3.714286
# Germany             3            60.204082             6.266667
# Brazil              5            70.786517             6.375000
#
#              cups_won_yearly
# team
# Argentina           0.153846
# Portugal            0.000000
# Netherlands         0.000000
# Germany             0.200000
# Brazil              0.312500
#
# [5 rows x 8 columns]

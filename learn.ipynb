# %%
from random import random

from IPython.display import HTML
import pygal
from sklearn.neighbors import KNeighborsClassifier

from utils import get_matches, get_team_stats, extract_samples, normalize, split_samples

# %% [markdown]
# Configs:

# %%
input_features = ['year',
                  'matches_won_percent',
                  'podium_score_yearly',
                  'matches_won_percent_2',
                  'podium_score_yearly_2']

output_feature = 'winner'

remove_ties = True

neighbors = 10

# %%
team_stats = get_team_stats()
team_stats.head()
# Out:
#                        matches_played  matches_won  years_played  \
# team
# Brazil                             89           63            16
# Canada                              3            0             1
# Serbia and Montenegro               3            0             1
# Kuwait                              3            0             1
# Scotland                           23            4             8
#
#                        podium_score  cups_won  matches_won_percent  \
# team
# Brazil                          102         5            70.786517
# Canada                            0         0             0.000000
# Serbia and Montenegro             0         0             0.000000
# Kuwait                            0         0             0.000000
# Scotland                          0         0            17.391304
#
#                        podium_score_yearly  cups_won_yearly
# team
# Brazil                               6.375           0.3125
# Canada                               0.000           0.0000
# Serbia and Montenegro                0.000           0.0000
# Kuwait                               0.000           0.0000
# Scotland                             0.000           0.0000
#
# [5 rows x 8 columns]

# %%
def teams_by_stat_graph(stat):
    sorted_team_stats = team_stats.sort(stat)
    graph = pygal.Bar()
    graph.config.show_legend = False
    graph.title = 'Teams by ' + stat
    graph.x_labels = list(sorted_team_stats.index)
    graph.add(stat, sorted_team_stats[stat])

    return HTML(graph.render())

# %%
teams_by_stat_graph('matches_won_percent')
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-f3d664d5-12c6-4426-9240-5fe09088a9bd" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 1.4.6 ©Kozea 2011-2014 on 2014-05-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .title{font-family:monospace;font-size:16px}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .legends .legend text{font-family:monospace;font-size:14px}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis text{font-family:monospace;font-size:10px}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis text.major{font-family:monospace;font-size:10px}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .series text{font-family:monospace;font-size:8px}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .tooltip text{font-family:monospace;font-size:16px}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd text.no_data{font-size:64px}
# #chart-f3d664d5-12c6-4426-9240-5fe09088a9bd{background-color:black}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd path,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd line,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd rect,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .graph &gt; .background{fill:black}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .plot &gt; .background{fill:#111}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .graph{fill:#999}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd text.no_data{fill:#eee}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .title{fill:#eee}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .legends .legend text{fill:#999}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .legends .legend:hover text{fill:#eee}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis .line{stroke:#eee}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis .guide.line{stroke:#555}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis .major.line{stroke:#999}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis text.major{stroke:#eee;fill:#eee}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis.y .guides:hover .guide.line,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .line-graph .axis.x .guides:hover .guide.line,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .stackedline-graph .axis.x .guides:hover .guide.line,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis .guides:hover text{fill:#eee}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .reactive{fill-opacity:.8}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .reactive.active,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .active .reactive{fill-opacity:.4}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .series text{fill:#eee}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .tooltip rect{fill:#111;stroke:#eee}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .tooltip text{fill:#eee}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .map-element{fill:#999;stroke:#555 !important;opacity:.9;stroke-width:3;-webkit-transition:250ms;-moz-transition:250ms;-o-transition:250ms;transition:250ms}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .map-element:hover{opacity:1;stroke-width:10}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-0,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-0 a:visited{stroke:#ff5995;fill:#ff5995}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-1,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-1 a:visited{stroke:#b6e354;fill:#b6e354}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-2,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-2 a:visited{stroke:#feed6c;fill:#feed6c}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-3,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-3 a:visited{stroke:#8cedff;fill:#8cedff}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-4,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-4 a:visited{stroke:#9e6ffe;fill:#9e6ffe}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-5,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-5 a:visited{stroke:#899ca1;fill:#899ca1}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-6,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-6 a:visited{stroke:#f8f8f2;fill:#f8f8f2}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-7,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-7 a:visited{stroke:#bf4646;fill:#bf4646}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-8,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-8 a:visited{stroke:#516083;fill:#516083}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-9,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-9 a:visited{stroke:#f92672;fill:#f92672}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-10,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-10 a:visited{stroke:#82b414;fill:#82b414}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-11,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .color-11 a:visited{stroke:# ...
# #chart-f3d664d5-12c6-4426-9240-5fe09088a9bd text.no_data{text-anchor:middle}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .guide.line{fill-opacity:0}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .centered{text-anchor:middle}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .title{text-anchor:middle}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .legends .legend text{fill-opacity:1}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis.x text{text-anchor:middle}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis.x:not(.web) text[transform]{text-anchor:start}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis.y text{text-anchor:end}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis.y2 text{text-anchor:start}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis.y .logarithmic text:not(.major),#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis.y2 .logarithmic text:not(.major){font-size:50%}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis .guide.line{stroke-dasharray:4,4}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis .major.guide.line{stroke-dasharray:6,6}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis text.major{stroke-width:0.5px}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .horizontal .axis.y .guide.line,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .horizontal .axis.y2 .guide.line,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .vertical .axis.x .guide.line{opacity:0}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .horizontal .axis.always_show .guide.line,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis.y .guides:hover .guide.line,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis.y2 .guides:hover .guide.line,#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis.x .guides:hover .guide.line{opacity:1}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .axis .guides:hover text{opacity:1}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .nofill{fill:none}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .subtle-fill{fill-opacity:.2}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .dot{stroke-width:1px;fill-opacity:1}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .dot.active{stroke-width:5px}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .series text{stroke:none}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .series text.active{opacity:1}#chart-f3d664d5-12c6-4426-9240-5fe09088a9bd .tooltip rect{fill-opacity:0.8}#chart-

# %%
teams_by_stat_graph('podium_score_yearly')
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-3eacdbbb-9df0-4200-889a-b372c21fb308" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 1.4.6 ©Kozea 2011-2014 on 2014-05-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .title{font-family:monospace;font-size:16px}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .legends .legend text{font-family:monospace;font-size:14px}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis text{font-family:monospace;font-size:10px}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis text.major{font-family:monospace;font-size:10px}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .series text{font-family:monospace;font-size:8px}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .tooltip text{font-family:monospace;font-size:16px}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 text.no_data{font-size:64px}
# #chart-3eacdbbb-9df0-4200-889a-b372c21fb308{background-color:black}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 path,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 line,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 rect,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .graph &gt; .background{fill:black}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .plot &gt; .background{fill:#111}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .graph{fill:#999}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 text.no_data{fill:#eee}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .title{fill:#eee}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .legends .legend text{fill:#999}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .legends .legend:hover text{fill:#eee}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis .line{stroke:#eee}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis .guide.line{stroke:#555}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis .major.line{stroke:#999}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis text.major{stroke:#eee;fill:#eee}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis.y .guides:hover .guide.line,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .line-graph .axis.x .guides:hover .guide.line,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis .guides:hover text{fill:#eee}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .reactive{fill-opacity:.8}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .reactive.active,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .active .reactive{fill-opacity:.4}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .series text{fill:#eee}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .tooltip rect{fill:#111;stroke:#eee}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .tooltip text{fill:#eee}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .map-element{fill:#999;stroke:#555 !important;opacity:.9;stroke-width:3;-webkit-transition:250ms;-moz-transition:250ms;-o-transition:250ms;transition:250ms}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .map-element:hover{opacity:1;stroke-width:10}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-0,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-0 a:visited{stroke:#ff5995;fill:#ff5995}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-1,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-1 a:visited{stroke:#b6e354;fill:#b6e354}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-2,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-2 a:visited{stroke:#feed6c;fill:#feed6c}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-3,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-3 a:visited{stroke:#8cedff;fill:#8cedff}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-4,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-4 a:visited{stroke:#9e6ffe;fill:#9e6ffe}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-5,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-5 a:visited{stroke:#899ca1;fill:#899ca1}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-6,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-6 a:visited{stroke:#f8f8f2;fill:#f8f8f2}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-7,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-7 a:visited{stroke:#bf4646;fill:#bf4646}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-8,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-8 a:visited{stroke:#516083;fill:#516083}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-9,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-9 a:visited{stroke:#f92672;fill:#f92672}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-10,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-10 a:visited{stroke:#82b414;fill:#82b414}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-11,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .color-11 a:visited{stroke:# ...
# #chart-3eacdbbb-9df0-4200-889a-b372c21fb308 text.no_data{text-anchor:middle}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .guide.line{fill-opacity:0}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .centered{text-anchor:middle}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .title{text-anchor:middle}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .legends .legend text{fill-opacity:1}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis.x text{text-anchor:middle}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis.y text{text-anchor:end}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis.y2 text{text-anchor:start}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis.y .logarithmic text:not(.major),#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis.y2 .logarithmic text:not(.major){font-size:50%}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis .guide.line{stroke-dasharray:4,4}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis .major.guide.line{stroke-dasharray:6,6}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis text.major{stroke-width:0.5px}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .horizontal .axis.y .guide.line,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .horizontal .axis.y2 .guide.line,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .vertical .axis.x .guide.line{opacity:0}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .horizontal .axis.always_show .guide.line,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis.y .guides:hover .guide.line,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis.y2 .guides:hover .guide.line,#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis.x .guides:hover .guide.line{opacity:1}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .axis .guides:hover text{opacity:1}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .nofill{fill:none}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .subtle-fill{fill-opacity:.2}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .dot{stroke-width:1px;fill-opacity:1}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .dot.active{stroke-width:5px}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .series text{stroke:none}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .series text.active{opacity:1}#chart-3eacdbbb-9df0-4200-889a-b372c21fb308 .tooltip rect{fill-opacity:0.8}#chart-

# %%
matches = get_matches(with_team_stats=True,
                      duplicate_with_reversed=True)

if remove_ties:
        matches = matches[matches['score1'] != matches['score2']]
        
matches.head()
# Out:
#    score1  score2        team1        team2  year  score_diff  winner  \
# 0       4       0       Brazil       Mexico  1950           4       1
# 1       3       0   Yugoslavia  Switzerland  1950           3       1
# 3       4       1   Yugoslavia       Mexico  1950           3       1
# 4       2       0       Brazil   Yugoslavia  1950           2       1
# 5       2       1  Switzerland       Mexico  1950           1       1
#
#    matches_played  matches_won  years_played  podium_score  cups_won  \
# 0              89           63            16           102         5
# 1              34           14             8             2         0
# 3              34           14             8             2         0
# 4              89           63            16           102         5
# 5              24            7             7             0         0
#
#    matches_won_percent  podium_score_yearly  cups_won_yearly  \
# 0            70.786517                6.375           0.3125
# 1            41.176471                0.250           0.0000
# 3            41.176471                0.250           0.0000
# 4            70.786517                6.375           0.3125
# 5            29.166667                0.000           0.0000
#
#    matches_played_2  matches_won_2  years_played_2  podium_score_2  \
# 0                46             12              13               0
# 1                24              7               7               0
# 3                46             12              13               0
# 4                34             14               8               2
# 5                46             12              13               0
#
#    cups_won_2
# 0           0 ...
# 1           0 ...
# 3           0 ...
# 4           0 ...
# 5           0 ...
#
# [5 rows x 23 columns]

# %%
def graph_results(feature_x, feature_y):
    wins1 = matches[matches.score1 > matches.score2]
    wins2 = matches[matches.score1 < matches.score2]
    ties = matches[matches.score1 == matches.score2]
    
    graph = pygal.XY(stroke=False)
    graph.title = 'Results dispersion by %s, %s' % (feature_x, feature_y)
    graph.add('wins 1', zip(wins1[feature_x], wins1[feature_y]))
    graph.add('wins 2', zip(wins2[feature_x], wins2[feature_y]))
    graph.add('ties', zip(ties[feature_x], ties[feature_y]))
    
    return HTML(graph.render())

# %%
graph_results('matches_won_percent', 'matches_won_percent_2')
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-2269a8a7-db71-424e-a08c-abd592bfe09c" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 1.4.6 ©Kozea 2011-2014 on 2014-05-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .title{font-family:monospace;font-size:16px}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .legends .legend text{font-family:monospace;font-size:14px}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis text{font-family:monospace;font-size:10px}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis text.major{font-family:monospace;font-size:10px}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .series text{font-family:monospace;font-size:8px}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .tooltip text{font-family:monospace;font-size:16px}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c text.no_data{font-size:64px}
# #chart-2269a8a7-db71-424e-a08c-abd592bfe09c{background-color:black}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c path,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c line,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c rect,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .graph &gt; .background{fill:black}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .plot &gt; .background{fill:#111}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .graph{fill:#999}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c text.no_data{fill:#eee}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .title{fill:#eee}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .legends .legend text{fill:#999}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .legends .legend:hover text{fill:#eee}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis .line{stroke:#eee}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis .guide.line{stroke:#555}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis .major.line{stroke:#999}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis text.major{stroke:#eee;fill:#eee}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis.y .guides:hover .guide.line,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .line-graph .axis.x .guides:hover .guide.line,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .stackedline-graph .axis.x .guides:hover .guide.line,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis .guides:hover text{fill:#eee}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .reactive{fill-opacity:.8}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .reactive.active,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .active .reactive{fill-opacity:.4}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .series text{fill:#eee}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .tooltip rect{fill:#111;stroke:#eee}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .tooltip text{fill:#eee}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .map-element{fill:#999;stroke:#555 !important;opacity:.9;stroke-width:3;-webkit-transition:250ms;-moz-transition:250ms;-o-transition:250ms;transition:250ms}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .map-element:hover{opacity:1;stroke-width:10}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-0,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-0 a:visited{stroke:#ff5995;fill:#ff5995}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-1,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-1 a:visited{stroke:#b6e354;fill:#b6e354}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-2,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-2 a:visited{stroke:#feed6c;fill:#feed6c}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-3,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-3 a:visited{stroke:#8cedff;fill:#8cedff}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-4,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-4 a:visited{stroke:#9e6ffe;fill:#9e6ffe}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-5,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-5 a:visited{stroke:#899ca1;fill:#899ca1}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-6,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-6 a:visited{stroke:#f8f8f2;fill:#f8f8f2}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-7,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-7 a:visited{stroke:#bf4646;fill:#bf4646}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-8,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-8 a:visited{stroke:#516083;fill:#516083}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-9,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-9 a:visited{stroke:#f92672;fill:#f92672}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-10,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-10 a:visited{stroke:#82b414;fill:#82b414}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-11,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .color-11 a:visited{stroke:# ...
# #chart-2269a8a7-db71-424e-a08c-abd592bfe09c text.no_data{text-anchor:middle}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .guide.line{fill-opacity:0}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .centered{text-anchor:middle}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .title{text-anchor:middle}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .legends .legend text{fill-opacity:1}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis.x text{text-anchor:middle}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis.x:not(.web) text[transform]{text-anchor:start}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis.y text{text-anchor:end}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis.y2 text{text-anchor:start}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis.y .logarithmic text:not(.major),#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis.y2 .logarithmic text:not(.major){font-size:50%}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis .guide.line{stroke-dasharray:4,4}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis .major.guide.line{stroke-dasharray:6,6}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis text.major{stroke-width:0.5px}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .horizontal .axis.y .guide.line,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .horizontal .axis.y2 .guide.line,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .vertical .axis.x .guide.line{opacity:0}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .horizontal .axis.always_show .guide.line,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis.y .guides:hover .guide.line,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis.y2 .guides:hover .guide.line,#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis.x .guides:hover .guide.line{opacity:1}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .axis .guides:hover text{opacity:1}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .nofill{fill:none}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .subtle-fill{fill-opacity:.2}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .dot{stroke-width:1px;fill-opacity:1}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .dot.active{stroke-width:5px}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .series text{stroke:none}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .series text.active{opacity:1}#chart-2269a8a7-db71-424e-a08c-abd592bfe09c .tooltip rect{fill-opacity:0.8}#chart-

# %%
graph_results('podium_score_yearly', 'podium_score_yearly_2')
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 1.4.6 ©Kozea 2011-2014 on 2014-05-07--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .title{font-family:monospace;font-size:16px}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .legends .legend text{font-family:monospace;font-size:14px}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis text{font-family:monospace;font-size:10px}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis text.major{font-family:monospace;font-size:10px}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .series text{font-family:monospace;font-size:8px}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .tooltip text{font-family:monospace;font-size:16px}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a text.no_data{font-size:64px}
# #chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a{background-color:black}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a path,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a line,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a rect,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a circle{-webkit-transition:250ms;-moz-transition:250ms;transition:250ms}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .graph &gt; .background{fill:black}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .plot &gt; .background{fill:#111}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .graph{fill:#999}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a text.no_data{fill:#eee}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .title{fill:#eee}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .legends .legend text{fill:#999}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .legends .legend:hover text{fill:#eee}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis .line{stroke:#eee}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis .guide.line{stroke:#555}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis .major.line{stroke:#999}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis text.major{stroke:#eee;fill:#eee}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis.y .guides:hover .guide.line,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .line-graph .axis.x .guides:hover .guide.line,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .stackedline-graph .axis.x .guides:hover .guide.line,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .xy-graph .axis.x .guides:hover .guide.line{stroke:#eee}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis .guides:hover text{fill:#eee}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .reactive{fill-opacity:.8}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .reactive.active,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .active .reactive{fill-opacity:.4}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .series text{fill:#eee}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .tooltip rect{fill:#111;stroke:#eee}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .tooltip text{fill:#eee}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .map-element{fill:#999;stroke:#555 !important;opacity:.9;stroke-width:3;-webkit-transition:250ms;-moz-transition:250ms;-o-transition:250ms;transition:250ms}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .map-element:hover{opacity:1;stroke-width:10}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-0,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-0 a:visited{stroke:#ff5995;fill:#ff5995}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-1,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-1 a:visited{stroke:#b6e354;fill:#b6e354}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-2,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-2 a:visited{stroke:#feed6c;fill:#feed6c}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-3,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-3 a:visited{stroke:#8cedff;fill:#8cedff}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-4,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-4 a:visited{stroke:#9e6ffe;fill:#9e6ffe}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-5,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-5 a:visited{stroke:#899ca1;fill:#899ca1}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-6,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-6 a:visited{stroke:#f8f8f2;fill:#f8f8f2}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-7,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-7 a:visited{stroke:#bf4646;fill:#bf4646}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-8,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-8 a:visited{stroke:#516083;fill:#516083}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-9,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-9 a:visited{stroke:#f92672;fill:#f92672}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-10,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-10 a:visited{stroke:#82b414;fill:#82b414}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-11,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .color-11 a:visited{stroke:# ...
# #chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a text.no_data{text-anchor:middle}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .guide.line{fill-opacity:0}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .centered{text-anchor:middle}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .title{text-anchor:middle}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .legends .legend text{fill-opacity:1}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis.x text{text-anchor:middle}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis.x:not(.web) text[transform]{text-anchor:start}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis.y text{text-anchor:end}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis.y2 text{text-anchor:start}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis.y .logarithmic text:not(.major),#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis.y2 .logarithmic text:not(.major){font-size:50%}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis .guide.line{stroke-dasharray:4,4}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis .major.guide.line{stroke-dasharray:6,6}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis text.major{stroke-width:0.5px}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .horizontal .axis.y .guide.line,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .horizontal .axis.y2 .guide.line,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .vertical .axis.x .guide.line{opacity:0}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .horizontal .axis.always_show .guide.line,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis.y .guides:hover .guide.line,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis.y2 .guides:hover .guide.line,#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis.x .guides:hover .guide.line{opacity:1}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .axis .guides:hover text{opacity:1}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .nofill{fill:none}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .subtle-fill{fill-opacity:.2}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .dot{stroke-width:1px;fill-opacity:1}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .dot.active{stroke-width:5px}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .series text{stroke:none}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .series text.active{opacity:1}#chart-e3f3436c-d19e-48c3-903f-bbef47bccc1a .tooltip rect{fill-opacity:0.8}#chart-

# %%
inputs, outputs = extract_samples(matches,
                                  input_features,
                                  output_feature)

normalizer, inputs = normalize(inputs)

train_inputs, train_outputs, test_inputs, test_outputs = split_samples(inputs, outputs)

classifier = KNeighborsClassifier(n_neighbors=neighbors)
classifier.fit(train_inputs, train_outputs)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            n_neighbors=10, p=2, weights='uniform')

# %%
classifier.score(test_inputs, test_outputs)
# Out:
# 0.7350427350427351
